# %% [markdown]
# <img src="https://www.ikiam.edu.ec/noticias/wp-content/uploads/2019/03/LOGO-IKIAM.png" width=300 height=240 />
#
# # EXAMEN PARCIAL PYTHON
#
#
# ## GBI6-2022II: BIOINFORMÁTICA
#
# <font color='blue'> Escudero Castellano Kimberly Escudero
#
# <font color='green'>**01-02-2022**
#
# <font color='red'><h1> tabla de datos de la computadora</h1>
# <table border="1">
#   <tr>
#       <td>nombre del dispositivo</td>
#       <td>kim</td>
#   </tr>
#   <tr>
#       <td>procesador</td>
#       <td>Intel(R)Celeron(R)N4020 CPU @ 1.10GHz</td>
#   </tr>
#   <tr>
#       <td>RAM instalada<!td>
#       <td>4.00gb<!td>
#   </tr>
#   <tr>
#       <td>tipo de sistema</td>
#       <td>sistema operativode 64bits</td>

# %% [markdown]
# ### REQUERIMIENTOS PARA EL EXAMEN
#
# Utilice de preferencia ```Jupyter``` de Anaconda, dado que tienen que hacer un control de cambios en cada pregunta.
#
# Para este examen se requiere dos documentos:
#
# 1. Archivo ```coati.py``` donde tendrá dos funciones:
#
# 2. Archivo ```2022II_GBI6_ExamenPython``` donde se llamará las funciones y se obtendrá resultados.

# %% [markdown]
# ## Ejercicio 0 [0.5 puntos]
# Realice cambios al cuaderno de jupyter:
# - Agregue el logo de la Universidad
# - Coloque sus datos personales
# - Escriba una <font color='red'>**tabla**</font> con las características de su computador

# %% [markdown]
# ## Ejercicio 1 [1.5 puntos]
# Inserte la captura de pantalla del curso [PANDAS](https://www.kaggle.com/learn/pandas) de Kaggle (Certificado y evidencia de avance de la página de Kaggle)
#
# <img src="data:image/png;base64,...">

# %% [markdown]
# ## Ejercicio 2 [1.5 puntos]
# Inserte la captura de pantalla del curso [VISUALIZACIÓN](https://www.kaggle.com/learn/data-visualization) de Kaggle (Certificado y evidencia de avance de la página de Kaggle)
#
# <img src="data:image/png;base64,...">

# %% [markdown]
# ## Ejercicio 3 [3 puntos]
#
# En su carpeta de examen tiene el documento ```id_coati.txt``` donde se encuentran los identificadores de accesión que debe usar para descargar información.
# Cree el módulo ```coati.py``` con las siguientes tres **funciones** y sus respectivos **docstring** :
#
# i. ```fasta_downloader```: para cargar ```id_coati.txt``` en ```id_coati```y descargar en **formato genbank** la información correspondiente a los identificadores de accesión usando el **ENTREZ** de Biopythony se guardar en ```coati``` y en ```coati.gb```.
#
# ii. ```alignment```: para que el algoritmo extraiga **solamente las secuencias** de la variable ```coati``` y realice un alineamiento usando clustalW. El resultado debe ser ```coati.aln``` y ```coati.dnd``` que deben guardarse en su carpeta de trabajo.
#
# iii ```tree```: para que realice el cálculo de las distancias utilizando ```coati.aln``` y finalmente que imprima en la pantalla el árbol filogenético y guarde en su carpeta de trabajo el arbol como ```coati_phylotree.pdf```
#
# iv. Cargue el módulo ```coati``` e **imprima docstring de cada función**.

# %%
def fasta_downloader(id_file):
    """Descarga secuencias en formato GenBank correspondientes a los identificadores de acceso en id_file y las guarda en archivos fasta y GenBank"""
    Entrez.email = 
    Entrez.email

    Entrez.
"your.email@example.com"
    with open(id_file, "r") as id_list:
        ids = id_list.read().splitlines()
        handle = Entrez.efetch(db=
        ids = id_list.read().splitlines()
        handle = Entrez.efetch(db

        ids = id_list.read().splitlines()
        handle = Entrez.efetch(

        ids = id_list.read().splitlines()
        handle = Entrez.ef

        ids = id_list.read().splitlines()
        handle = Entrez.

        ids = id_list.read().splitlines()

        ids = 
        ids =
"nucleotide", id=ids, rettype="gb", retmode="text")
        records = 
        records =
list(SeqIO.parse(handle, "gb"))
        fasta_file = 
        fasta_file

        fasta_
"coati.fasta"
        genbank_file = 
        genbank_file

        genbank_
"coati.gb"
        SeqIO.write(records, fasta_file, 
        SeqIO.write(records, fasta_file

        SeqIO.write(records, fasta_

        SeqIO.write(records, fast

        SeqIO.write(records,

        SeqIO.write(records
"fasta")
        SeqIO.write(records, genbank_file, 
        SeqIO.write(records, genbank_file

        SeqIO.write(records, genbank_

        SeqIO.write(records, gen

        SeqIO.write(records,

        SeqIO.write(records
"gb")
    return None

def alignment(fasta_file):
    """Realiza un alineamiento de secuencias en el archivo fasta_file y guarda los resultados en archivos .aln y .dnd"""
    clustalw_cline = ClustalwCommandline(
    clustalw_cline = ClustalwCommandline

    clustalw_cline = ClustalwCommand

    clustalw_cline = Cl

    clustalw_cline =

    clustalw_cline

    clustalw_cl

    clustalw_

    clustalw

    clustal
"clustalw", infile=fasta_file)
    clustalw_cline()
    aln_file = 
    clustalw_cline()
    aln_file

    clustalw_cline()
    aln_

    clustalw_cline()

    clustalw_cl

    clustalw_

    clust
"coati.aln"
    dnd_file = 
    dnd_file

    dnd_
"coati.dnd"
    return None

def tree(aln_file):
    """Calcula las distancias a partir del archivo de alineamiento aln_file y imprime y guarda el árbol filogenético en un archivo pdf"""
    calculator = DistanceCalculator(
    calculator = DistanceCal

    calculator = Distance

    calculator = 

    calculator =
'clustalw')
    dm = calculator.get_distance(aln_file)
    constructor = DistanceTreeConstructor(calculator, 
    dm = calculator.get_distance(aln_file)
    constructor = DistanceTreeConstructor(calculator,

    dm = calculator.get_distance(aln_file)
    constructor = DistanceTreeConstructor(

    dm = calculator.get_distance(aln_file)
    constructor = DistanceTreeConstructor

    dm = calculator.get_distance(aln_file)
    constructor = DistanceTreeConstruct

    dm = calculator.get_distance(aln_file

    dm = calculator.get_distance(aln_

    dm = calculator.get_distance

    dm = calculator.get_

    dm = calculator.get

    dm = calculator.

    dm = calculator

    dm =
'nj')
    tree = constructor.build_tree(dm)
    tree.ladderize()
    tree.rooted = 
    tree = constructor.build_tree(dm)
    tree.ladderize()
    tree.rooted =

    tree = constructor.build_tree(dm)
    tree.ladderize()
    tree.ro

    tree = constructor.build_tree(dm)
    tree.ladderize()
    tree.

    tree = constructor.build_tree(dm)
    tree.ladderize()
   

    tree = constructor.build_tree(dm)
    tree.ladderize()

    tree = constructor.build_tree(dm)
    tree.ladderize

    tree = constructor.build_tree(dm)
    tree.lad

    tree = constructor.build_tree(dm)
    tree.

    tree = constructor.build_tree(dm)

    tree = constructor.build_tree(dm

    tree = constructor.build_tree(

    tree = constructor.build_tree

    tree = constructor

    tree =
True
    tree.ladderize()
    tree.display()
    tree.write(
    tree.ladderize()
    tree.display()
    tree.write

    tree.ladderize()
    tree.display()
    tree.

    tree.ladderize()
    tree.display()
    tree

    tree.ladderize()
    tree.display

    tree.ladderize()
    tree.

    tree.ladderize()

    tree.ladderize

    tree.lad

    tree.
"coati_phylotree.pdf", "pdf")
    return None

# %% [markdown]
# ## Ejercicio 4 [1.5 puntos]
#
# Escriba una o dos líneas de código para usar las funciones ```fasta_downloader```, ```alignment``` y ```tree```:
#
# i. Descargue la data en ```coati``` y guarde como ```coati.gdb```.
#
# ii. Alinee las secuencias de ```coati``` y obtenga ```coati.aln``` y ```coati.dnd```.
#
# iii. Construya e **interprete** el arbol filogenético y guarde en ```coati_phylotree.pdf```.

# %%
id_

coati.fasta_downloader(id_file)


coati.fasta_downloader(

coati.fasta_download

coati.fasta_

coati.fast

coati.

co

fasta_file

fasta_

fast
import coati

# Descarga la data en formato GenBank y guarda como coati.gb
id_file = "id_coati.txt"
coati.fasta_downloader(id_file)

# Alinea las secuencias de coati y obtiene coati.aln y coati.dnd
fasta_file = "coati.fasta"
coati.alignment(fasta_file)


coati.alignment(fasta_file

coati.alignment(fasta_

coati.alignment(fast

coati.al

coati.
# Construye e interpreta el árbol filogenético y lo guarda en coati_phylotree.pdf
aln_file = 
aln_file

aln_

al
"coati.aln"
coati.tree(aln_file)

coati.tree(aln_file

coati.tree(aln_

coati.tree(al

coati.tree(

coati.tree

coati.

# %% [markdown]
# ## Ejercicio 5 [1.5 puntos]
#
# Con las secuencias de ADN de ```coati```, realice lo siguiente:
#
# i. la traducción y cálculo del peso molecular (**molecular_weight**) y el índice de estabilidad (**instability_index**) de los péptidos resultantes.
#
# ii. una gráfica tipo [joinplot](https://seaborn.pydata.org/generated/seaborn.jointplot.html#seaborn.jointplot) utilizando los parámetros de peso molecular e índice de estabilidad. Edite color, tamaño y tipo de puntos, asimismo etiquete adecuadamente el título y los ejes.
#
# iii. guarde la figura como ```coati.png``` con una resolución de 300dpi.
#
# iv. interprete la figura resultante

# %%
# Escriba aquí su código para el ejercicio 5

# %% [markdown]
# ## Ejercicio 6 [0.5 puntos]
#
#
# 1. Cree un archivo ```Readme.md``` que debe tener lo siguiente:
# - Datos personales
# - Características del computador
# - Versión de Python/Anaconda y de cada uno de los módulos/paquetes y utilizados
# - Explicación de la data utilizada
#
# 2. Asegurarse que su repositorio tiene las carpetas ```data``` e ```img``` con los archivos que ha ido guardando en las preguntas anteriores.
# 3. Realice al menos 1 control de la versión (commits) por cada ejercicio (del 1 al 5), con un mensaje que inicie como:
#
# ```sh
# Carlitos Alimaña ha realizado el ejercicio 1
# ```
# ```sh
# Carlitos Alimaña ha realizado el ejercicio 2
# ```
# ```sh
# ...
# ```
